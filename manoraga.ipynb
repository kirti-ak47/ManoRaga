# %%
# !pip install -q google-generativeai

# %%
# !pip install google-genai
# Out:
# ...
#    ---------------------------------------- 0.0/724.2 kB ? eta -:--:--
#    ---------------------------------------- 724.2/724.2 kB 7.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 10.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.20.1
#     Uninstalling pydantic_core-2.20.1:
#       Successfully uninstalled pydantic_core-2.20.1
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.8.2
#     Uninstalling pydantic-2.8.2:
#       Successfully uninstalled pydantic-2.8.2
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDAG6UBobmQoS6_8yb8g77hyoe1O_CHAGk")

for m in genai.list_models():
    if "generateContent" in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025

# %%
model = genai.GenerativeModel("models/gemini-flash-latest")

# %%
import pandas as pd

raga_df = pd.read_csv("raga_data.csv")
raga_df
# Out:
#           Raga  Emotion                              Effect
# 0        Yaman     Calm  Reduces anxiety and improves focus
# 1     Bhairavi  Sadness          Provides emotional healing
# 2      Darbari   Stress       Deep relaxation and grounding
# 3  Hamsadhwani      Joy       Boosts positivity and clarity

# %%
def generate_raga_recommendation(user_feeling):
    raga_info = raga_df.to_string(index=False)

    prompt = f"""
You are a neuromusicology expert and Indian classical music scholar.

Below is a dataset of Indian ragas and their emotional benefits:
{raga_info}

User emotional state:
"{user_feeling}"

Tasks:
1. Identify the dominant emotion.
2. Choose the BEST matching raga ONLY from the dataset.
3. Explain how this raga helps mental and emotional well-being.
4. Keep the explanation calming, simple, and supportive.
"""

    response = model.generate_content(prompt)
    return response.text

# %%
user_input = input("Describe how you are feeling right now: ")
# Out:
# Describe how you are feeling right now:  I feel anxious and overthinking a lot

# %%
result = generate_raga_recommendation(user_input)
print("\n🎵 ManoRaga Recommendation\n")
print(result)
# Out:
# 🎵 ManoRaga Recommendation
#
# This is a perfect scenario for neuromusicological intervention through Indian Classical Music.
#
# ---
#
# ### 1. Dominant Emotion
#
# The dominant emotion is **Anxiety** (specifically linked to **Overthinking** and **Lack of Focus**).
#
# ### 2. Best Matching Raga
#
# The best matching raga from the dataset is **Yaman**.
#
# ### 3. Explanation: How Raga Yaman Helps
#
# Raga Yaman is often referred to as the 'King of Evening Ragas' and is deeply rooted in the philosophy of stability and resolution. It is uniquely powerful in addressing anxiety and overthinking through its structure:
#
# *   **Soothing Ascendancy:** Yaman utilizes the sharp major scale (Kalyan Thaat), but its melodic movement (or *chalan*) is characterized by slow, dignified ascending phrases. When you are overthinking, your mind is jumping chaotically. Yaman gently guides the auditory cortex along a predictable, beautiful path, reducing the neural noise associated with worry.
# ...
